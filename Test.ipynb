# %%
with open ("sample.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# Hii I am Ayush and I have started learning Data Science

# %%
with open ("Sample.txt", "w") as f:
    content = """Hii, I'm Khushi.
    I'm pursuing my B-Pharma Degree from KashiBai Navale College of Pharmacy"""
    f.write(content)
