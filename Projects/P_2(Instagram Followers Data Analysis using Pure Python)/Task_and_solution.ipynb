# %% [markdown]
# # Collect raw Instagram data of all OpenAI followers
#
# Answer these questions:
#
#     - Who has the maximum posts.
#     - Who has the maximum followers.
#     - Who follows the maximum people.
#     - How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
#     - How many people do we have?
#
# Note - At starting we will use the 'initialdata.txt' to write tye code then we will work on 'finaldata.txt'.

# %%
with open ("finaldata.txt", "r", encoding="utf-8") as f:
    data = f.read()

# %%
# print(data)

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]

# %%
# print(chunks)

# %%
# chunks[0]

# %%
print(len(chunks))
# Out:
# 107

# %%
def chunk_detail(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split("\n")
    user_name = sep_chunk[0]
    no_of_post = int(sep_chunk[1].split(" post")[0].replace(",", ""))
    no_of_followers = float(sep_chunk[2].split("follower")[0].replace(",", "").replace("K", "").replace("M", ""))
    if "K" in sep_chunk[2]:
        no_of_followers = int(no_of_followers*1000)
    elif "M" in sep_chunk[2]:
        no_of_followers = int(no_of_followers*100000)
    else:
        no_of_followers = int(no_of_followers)
    
    no_of_followings = float(sep_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))
    if "K" in sep_chunk[3]:
        no_of_followings = int(no_of_followings*1000)
    elif "M" in sep_chunk[3]:
        no_of_followings = int(no_of_followingss*100000)
    else:
        no_of_followings = int(no_of_followings)
    
    name = sep_chunk[4]
    if len(sep_chunk)>5:
        type_of_profile = sep_chunk[5]
        bio = "\n".join(sep_chunk[6:])
    else:
        type_of_profile = "Unknown"
        bio = "Empty"
    # print(user_name, no_of_post, no_of_followers, no_of_followings, name, type_of_profile, bio, sep="\n")
    return {"User_name":user_name, 
            "No_of_post":no_of_post, 
            "No_of_followers":no_of_followers, 
            "No_of_followings":no_of_followings, 
            "Name":name, 
            "Type_of_profile":type_of_profile, 
            "Bio":bio}

# %%
# chunk_detail(chunks[0])

# %%
detail = [chunk_detail(chunk) for chunk in chunks ]
# print(detail)


# detail= [] 
# for chunk in chunks: 
#     parsed_chunk = chunk_detail(chunk) 
#     detail.append(parsed_chunk) 
# print(detail)

# %%
import json
s = json.dumps(detail, indent=4)
with open ("data.json", "w") as f:
    f.write(s)

print(s)
# Out:
# [
#     {
#         "User_name": "techie_koramangala",
#         "No_of_post": 420,
#         "No_of_followers": 9800,
#         "No_of_followings": 310,
#         "Name": "Arjun M.",
#         "Type_of_profile": "Software Engineer",
#         "Bio": "\ud83d\udcbb Full-stack @ SaaS startup\n\u2615 Working from cafes in Koramangala\ngithub.com/arjunmakes"
#     },
#     {
#         "User_name": "blrcoder_girl",
#         "No_of_post": 150,
#         "No_of_followers": 6300,
#         "No_of_followings": 120,
#         "Name": "Riya Codes",
#         "Type_of_profile": "Tech Creator",
#         "Bio": "\ud83d\udc69\u200d\ud83d\udcbb Python | ML | Roadmaps\n\ud83c\udfa5 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes"
#     },
#     {
#         "User_name": "hsr_startup_stories",
#         "No_of_post": 980,
#         "No_of_followers": 22400,
#         "No_of_followings": 95,
#         "Name": "Startup Stories HSR",
#         "Type_of_profile": "Media",
# ...

# %%
#Who has the Maximum post
max = 0
for chunk in detail:
    if max<chunk["No_of_post"]:
        max = chunk["No_of_post"]
        acc_with_max_post = chunk
print(acc_with_max_post)
# Out:
# {'User_name': 'startuphub_blr', 'No_of_post': 2300, 'No_of_followers': 45000, 'No_of_followings': 120, 'Name': 'Startup Hub Bangalore', 'Type_of_profile': 'Media', 'Bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %%
#Who has the Maximum followers
max = 0
for chunk in detail:
    if max<chunk["No_of_followers"]:
        max = chunk["No_of_followers"]
        acc_with_max_followers = chunk
print(acc_with_max_followers)
# Out:
# {'User_name': '_anujsinghal', 'No_of_post': 1785, 'No_of_followers': 681000, 'No_of_followings': 248, 'Name': 'Anuj Singhal', 'Type_of_profile': 'Digital creator', 'Bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %%
# Who follows the Maximum people
max = 0
for chunk in detail:
    if max<chunk["No_of_followings"]:
        max = chunk["No_of_followings"]
        acc_with_max_followings = chunk
print(acc_with_max_followings)
# Out:
# {'User_name': 'bangalore_tech_bro', 'No_of_post': 402, 'No_of_followers': 12500, 'No_of_followings': 890, 'Name': 'Rahul | HSR Hustler', 'Type_of_profile': 'Entrepreneur', 'Bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %%
#How many categories (Digital creators, Non-profit foundation, etc do we have?
category = set()
print("User_name - Category") 
for chunk in detail:
    print(f"\n{chunk["User_name"]} - {chunk["Type_of_profile"]}")
    category.add(chunk["Type_of_profile"])
print("\n\nSet of categories are -", category)
# Out:
# User_name - Category
#
# techie_koramangala - Software Engineer
#
# blrcoder_girl - Tech Creator
#
# hsr_startup_stories - Media
#
# cloud_dev_blr - Engineer
#
# koramangala_coffee_lover - Cafe Explorer
#
# ai_bangalore_news - Media
#
# techfounder_india - Founder
#
# coder_on_orr - Backend Developer
#
# blrdatascience_daily - Media
#
# frontend_with_megha - Frontend Dev
#
# cubbonpark_runner - Lifestyle
#
# indiranagar_food_maps - Food & Drink
#
# python_blr_jobs - Community
#
# sarjapur_coder - Full-stack Dev
#
# open_source_blr - Community
#
# techwalk_blr - Media
#
# itpl_daily - Blog
#
# react_native_blr - Community
#
# founder_doodles - Artist + Coder
#
# blrproductmanager - Product Manager
#
# machinelearning_blr - Community
#
# bengaluru_startup_recruiter - Recruiter
#
# coffeeandcode_blr - Developer
#
# uiux_blr_design - Design
#
# whitefield_cafe_explorer - Cafe Nerd
#
# jslover_bangalore - Engineer
#
# blrautotechtalk - Media
#
# deeptech_india - Media
#
# ...

# %%
 #How many people do we have?
print("Total number of people we have in dataset are- ", len(chunks))
for chunk in detail:
    print(f"\n{chunk["User_name"]} - {chunk["Name"]}")
# Out:
# Total number of people we have in dataset are-  107
#
# techie_koramangala - Arjun M.
#
# blrcoder_girl - Riya Codes
#
# hsr_startup_stories - Startup Stories HSR
#
# cloud_dev_blr - Naveen DevOps
#
# koramangala_coffee_lover - Sana B.
#
# ai_bangalore_news - AI Bangalore
#
# techfounder_india - Dev Patel
#
# coder_on_orr - Sriram
#
# blrdatascience_daily - Bangalore DS Daily
#
# frontend_with_megha - Megha Gupta
#
# cubbonpark_runner - Aman
#
# indiranagar_food_maps - Food Maps BLR
#
# python_blr_jobs - Python Jobs BLR
#
# sarjapur_coder - Roshan
#
# open_source_blr - BLR Open Source
#
# techwalk_blr - Tech Walk Bangalore
#
# itpl_daily - ITPL Daily
#
# react_native_blr - RN Bangalore
#
# founder_doodles - Kushal
#
# blrproductmanager - Sanya | PM
#
# machinelearning_blr - ML Bangalore
#
# bengaluru_startup_recruiter - Ankita HR
#
# coffeeandcode_blr - Aditya
#
# uiux_blr_design - UI/UX Bangalore
#
# whitefield_cafe_explorer - Radhika
#
# jslover_bangalore - Jatin Codes
#
# ...
