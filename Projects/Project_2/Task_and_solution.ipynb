# %% [markdown]
# Collect raw Instagram data of all OpenAI followers
#
# Answer these questions:
#     -Who has the maximum posts
#     -Who has the maximum followers
#     -Who follows the maximum people
#     -How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?

# %%
with open ("initialdata.txt", "r", encoding="utf-8") as f:
    data = f.read()

# %%
print(data)
# Out:
# intaglobal
# 1,946 posts
# 6,851 followers
# 262 following
# INTA
# Nonprofit organization
# The association of ™ professionals.
# inta.campsite.bio
#
# _anujsinghal
# 1,785 posts
# 681K followers
# 248 following
# Anuj Singhal
# Digital creator
# Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India
# Let’s talk about finance and life
# Contact: Singhalanuj1010@gmail.com
# hindi.cnbctv18.com/market-gurukul
#
# code_flare
# 165 posts
# 216 followers
# 10 following
# The Journey Notebook | Travel | Food Blogger
# Blogger
# 📍 Exploring places & phases of life 🌍
# .
# 🍵 From chai breaks to flight takes ✈️
# .
# 💫 Travel | Food | Daily life 🌸
# youtube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a
#
# bangalore_tech_bro
# 402 posts
# 12.5K followers
# 890 following
# Rahul | HSR Hustler
# Entrepreneur
# 🚀 Building the next Unicorn in Fintech
# ☕ 3rd Wave Coffee addict
# 💻 Python | React | AI
# 📍 HSR Layout, BLR
# linktr.ee/rahulbuilds
#
# silkboard_survivor
# 55 posts
# 1,200 followers
# 50 following
# Priya D.
# Public Figure
# 🚦 Stuck in traffic since 2019
# 🌧️ Loving the Bangalore weather, hating the cabs
# 🐍 Data Scientist by day, meme maker by night
# 📍 ORR
# bit.ly/my-traffic-rants
#
# startuphub_blr
# 2,300 posts
# 45K followers
# 120 following
# Startup Hub Bangalore
# Media
# 🦄 News from the Silicon Valley of India
# 📢 Funding alerts, Hiring trends, and Drama
# 📩 DM for features
# startuphub.blr/newsletter
#
# foodie_in_kora
# 890 posts
# 5,600 followers
# 400 following
# Sneha | Bangalore Eats
# Food & Drink
# Aagrah to Truffles 🍔
# Exploring Koramangala's cafe culture ☕
# DM for collabs
# https://www.google.com/search?q=zomato.com/users/sneha123
#
# venture_vikram
# 120 posts
# 30K followers
# 500 following
# Vikram | Angel Investor
# Investor
# 💸 Helping founders go 0 to 1
# Ex-Google, Ex-Amazon
# Investing in DeepTech & AI
# 📍 Indiranagar
# vikram.vc/pitch-deck
#
# python_meetup_blr
# 60 posts
# 3,400 followers
# 10 following
# PyBangalore Community
# Community
# 🐍 Weekly meetups for Pythonistas
# 📍 Cubbon Park | Sundays 4 PM
# Coding + Coffee + Community
# https://www.google.com/search?q=meetup.com/pybangalore
#
# indiranagar_gossip
# 300 posts
# 8,900 followers
# 20 following
# Indiranagar Spy
# Personal Blog
# Not just about 100ft Road 🤫
# Spilling tea on the best brunches and worst landlords
# Bengaluru
# https://www.google.com/search?q=medium.com/%40indiranagarspy
#
#
# ig_arbin07
# 50 posts
# 33 followers
# 30 following
# aarbinnn
# Gamer
# @dumb.arbin
# 🎮: Banana『juice (IGL🥷)
# Gamer never die, they just respawn🙂‍↔️
#
#
#
# 7iiuliiu
# 1 post
# 44 followers
# 166 following
# ︎𝐄︎ ♡︎.
#
#
# katiasales2220
# 107 posts
# 219 followers
# 1,401 following
# Katia Sales
# Alfabetização e Reforço Escolar
# Ensino Fundamental I e II
# Preparação para Escola Militar
# Português e Matemática
# Cursando Psicopedagogia Estácio

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(chunks)>4]

# %%
print(chunks)
# Out:
# ['intaglobal\n1,946 posts\n6,851 followers\n262 following\nINTA\nNonprofit organization\nThe association of ™ professionals.\ninta.campsite.bio', '_anujsinghal\n1,785 posts\n681K followers\n248 following\nAnuj Singhal\nDigital creator\nManaging Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul', 'code_flare\n165 posts\n216 followers\n10 following\nThe Journey Notebook | Travel | Food Blogger\nBlogger\n📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a', 'bangalore_tech_bro\n402 posts\n12.5K followers\n890 following\nRahul | HSR Hustler\nEntrepreneur\n🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds', 'silkboard_survivor\n55 posts\n1,200 followers\n50 following\nPriya D.\nPublic Figure\n🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants', 'startuphub_blr\n2,300 posts\n45K followers\n120 following\nStartup Hub Bangalore\nMedia\n🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter', "foodie_in_kora\n890 posts\n5,600 followers\n400 following\nSneha | Bangalore Eats\nFood & Drink\nAagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123", 'venture_vikram\n120 posts\n30K followers\n500 following\nVikram | Angel Investor\nInvestor\n💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck', 'python_meetup_blr\n60 posts\n3,400 followers\n10 following\nPyBangalore Community\nCommunity\n🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore', 'indiranagar_gossip\n300 posts\n8,900 followers\n20 following\nIndiranagar Spy\nPersonal Blog\nNot just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy', '\nig_arbin07\n50 posts\n33 followers\n30 following\naarbinnn\nGamer\n@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️', '', '7iiuliiu\n1 post\n44 followers\n166 following\n︎𝐄︎ ♡︎.', '\nkatiasales2220\n107 posts\n219 followers\n1,401 following\nKatia Sales\nAlfabetização e Reforço Escolar\nEnsino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio']

# %%
chunks[0]
# Out:
# 'intaglobal\n1,946 posts\n6,851 followers\n262 following\nINTA\nNonprofit organization\nThe association of ™ professionals.\ninta.campsite.bio'

# %%
print(len(chunks))
# Out:
# 14

# %%
def chunk_detail(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split("\n")
    user_name = sep_chunk[0]
    no_of_post = int(sep_chunk[1].split(" post")[0].replace(",", ""))
    no_of_followers = float(sep_chunk[2].split("follower")[0].replace(",", "").replace("K", "").replace("M", ""))
    if "K" in sep_chunk[2]:
        no_of_followers = int(no_of_followers*1000)
    elif "M" in sep_chunk[2]:
        no_of_followers = int(no_of_followers*100000)
    else:
        no_of_followers = int(no_of_followers)
    
    no_of_followings = float(sep_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))
    if "K" in sep_chunk[3]:
        no_of_followings = int(no_of_followings*1000)
    elif "M" in sep_chunk[3]:
        no_of_followings = int(no_of_followingss*100000)
    else:
        no_of_followings = int(no_of_followings)
    
    name = sep_chunk[4]
    if len(sep_chunk)>5:
        type_of_profile = sep_chunk[5]
        bio = "\n".join(sep_chunk[6:])
    else:
        type_of_profile = "Unknown"
        bio = "Empty"
    # print(user_name, no_of_post, no_of_followers, no_of_followings, name, type_of_profile, bio, sep="\n")
    return {"User_name":user_name, 
            "No_of_post":no_of_post, 
            "No_of_followers":no_of_followers, 
            "No_of_followings":no_of_followings, 
            "Name":name, 
            "Type_of_profile":type_of_profile, 
            "Bio":bio}

# %%
# chunk_detail(chunks[0])

# %%
detail = [chunk_detail(chunk) for chunk in chunks ]
print(detail)


# detail= [] 
# for chunk in chunks: 
#     parsed_chunk = chunk_detail(chunk) 
#     detail.append(parsed_chunk) 
# print(detail)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 detail = [chunk_detail(chunk) for chunk in chunks ]
#       2 print(detail)
#       5 # detail= []
#       6 # for chunk in chunks:
#       7 #     parsed_chunk = chunk_detail(chunk)
#       8 #     detail.append(parsed_chunk)
#       9 # print(detail)
#
# Cell In[16], line 5, in chunk_detail(chunk)
#       3 sep_chunk = chunk.split("\n")
#       4 user_name = sep_chunk[0]
# ----> 5 no_of_post = int(sep_chunk[1].split(" post")[0].replace(",", ""))
#       6 no_of_followers = float(sep_chunk[2].split("follower")[0].replace(",", "").replace("K", "").replace("M", ""))
#       7 if "K" in sep_chunk[2]:
#
# IndexError: list index out of range

# %%
import json
s = json.dumps(detail, indent=4)
print(s)

# %%
#Who has the Maximum post
max = 0
for chunk in detail:
    if max<chunk["No_of_post"]:
        max = chunk["No_of_post"]
        acc_with_max_post = chunk
print(acc_with_max_post)

# %%
#Who has the Maximum followers
max = 0
for chunk in detail:
    if max<chunk["No_of_followers"]:
        max = chunk["No_of_followers"]
        acc_with_max_followers = chunk
print(acc_with_max_followers)

# %%
# Who follows the Maximum people
max = 0
for chunk in detail:
    if max<chunk["No_of_followings"]:
        max = chunk["No_of_followings"]
        acc_with_max_followings = chunk
print(acc_with_max_followings)

# %%
#How many categories (Digital creators, Non-profit foundation, etc do we have?
print("User_name - Category") 
for chunk in detail:
    print(f"\n{chunk["User_name"]} - {chunk["Type_of_profile"]}")

# %%
 #How many people do we have?
print("Total number of people we have in dataset are- ", len(chunks))
for chunk in detail:
    print(f"\n{chunk["User_name"]} - {chunk["Name"]}")
